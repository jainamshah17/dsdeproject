# %%
### Imports
import os
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# Constants
DATA_PATH = "./raw/"

# %% [markdown]
# # Data Preparation

# %%
# Load dataset
files = []
for file in os.listdir(DATA_PATH):
    if file.endswith(".csv"):
        files.append(file)

dfs = []
for file in files:
    d = pd.read_csv(DATA_PATH + file)
    d["region"] = file[0:2]
    dfs.append(d)

df = pd.concat(dfs, axis = 0)
df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
# Handling null / missing values
df.isna().sum()
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               7503
# region                       0
# dtype: int64

# %%
df = df.drop(columns = ["description"])
df.isna().sum()
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# region                    0
# dtype: int64

# %% [markdown]
# We have dropped the description column due to null values. Description column requires natural language processing (NLP) related models for analysis, which is out of the scope of our project. We focus more on analysing statistical features like number of views, trending dates, number of likes & comments, etc. on the youtube videos.
